# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the train directory path
train_dir = '/content/drive/MyDrive/FruitinAmazon/train'
test_dir = '/content/drive/MyDrive/FruitinAmazon/test'

# Get the list of class directories
class_dirs = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]
class_dirs.sort()  # Sort for consistent order
print(f"Found {len(class_dirs)} classes: {class_dirs}")

# Select one random image from each class
images = []
class_names = []
for class_dir in class_dirs:
    class_path = os.path.join(train_dir, class_dir)
    image_files = [f for f in os.listdir(class_path) if f.endswith(('.jpg', '.jpeg', '.png'))]
    if image_files:  # Ensure there’s at least one image
        random_image = random.choice(image_files)
        image_path = os.path.join(class_path, random_image)
        images.append(image_path)
        class_names.append(class_dir)

# Check if we have images to display
if not images:
    raise ValueError("No images found in the dataset!")

# Display images in a 2-row grid
rows = 2
cols = (len(images) + 1) // 2  # Ceiling division to fit all classes
fig, axes = plt.subplots(rows, cols, figsize=(15, 10))  # Adjust figure size as needed
fig.suptitle("Random Images from Each Class", fontsize=16)

# Flatten axes array for easier indexing
axes = axes.flatten()

# Plot each image
for i, (image_path, class_name) in enumerate(zip(images, class_names)):
    img = mpimg.imread(image_path)
    axes[i].imshow(img)
    axes[i].set_title(class_name)
    axes[i].axis('off')  # Hide axes

# Hide any unused subplots (if odd number of classes)
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Found 6 classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %%
import os

# Dictionary to store class counts
class_counts = {}
for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        images = [img for img in os.listdir(class_path) if img.lower().endswith(('.png', '.jpg', '.jpeg'))]
        class_counts[class_name] = len(images)  # Count images in each class

# Print Class Balance
print("\nClass Distribution:")
print("=" * 45)
print(f"{'Class Name':<25}{'Valid Image Count':>15}")
print("=" * 45)

for class_name, count in class_counts.items():
    print(f"{class_name:<25}{count:>15}")

print("=" * 45)  # Closing separator
# Out:
# Class Distribution:
# =============================================
# Class Name               Valid Image Count
# =============================================
# acai                                  15
# cupuacu                               15
# graviola                              15
# guarana                               15
# pupunha                               15
# tucuma                                15
# =============================================

# %%
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Define image size and batch size
img_size = (224, 224)
batch_size = 32

# Load train and test datasets
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=img_size,
    batch_size=batch_size
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    shuffle=False,
    image_size=img_size,
    batch_size=batch_size
)

# Define data augmentation
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# Visualizing augmented images
def visualization(dataset):
    plt.figure(figsize=(7, 7))

    for images, _ in dataset.take(1):  # Take one batch
        for i in range(6):  # Show 6 images
            image = tf.expand_dims(images[i], axis=0)  # Expand dimensions to match batch format
            augmented_img = data_augmentation(image)  # Apply augmentation
            augmented_img = tf.squeeze(augmented_img)  # Remove batch dimension

            plt.subplot(3, 3, i + 1)
            plt.imshow(augmented_img.numpy().astype("uint8"))
            plt.axis("off")

    plt.show()

# Call the function (must be outside the function definition)
visualization(train_dataset)
# Out:
# Found 90 files belonging to 6 classes.
# Found 30 files belonging to 6 classes.

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation, Lambda, Rescaling
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np


# Define the model using the Sequential API with a list of layers
model = Sequential([
    # Data augmentation applied using Lambda layer
    layers.Lambda(data_augmentation, input_shape=(224, 224, 3)),
    # Rescaling layer to normalize pixel values
    layers.Rescaling(1./255),
    # First Convolutional Block
    Conv2D(32, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    # Second Convolutional Block
    Conv2D(64, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    # Third Convolutional Block
    Conv2D(128, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    # Fourth Convolutional Block
    Conv2D(256, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    # Flatten the output of the last Conv2D layer
    Flatten(),
    # First Fully Connected Layer
    Dense(512, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),
    # Second Fully Connected Layer
    Dense(256, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),
    # Third Fully Connected Layer
    Dense(128, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),
    # Fourth Fully Connected Layer
    Dense(64, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),
    # Output Layer with 10 neurons (for classification task with 10 classes)
    Dense(10, activation='softmax')
])

# Compile the model with Adam optimizer, sparse categorical crossentropy loss, and accuracy as the metric
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',  # Use this for integer labels
              metrics=['accuracy'])


# Summary of the model
model.summary()

checkpoint = ModelCheckpoint(
    'best_model.keras',  # Save best model
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=20,  # Stop after 20 epochs with no improvement
    mode='max',
    verbose=1
)
# Train model
histroy = model.fit(
    train_dataset,
    epochs=50,
    validation_data=test_dataset,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/lambda_layer.py:65: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lambda (Lambda)                      │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling (Rescaling)                │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 224, 224, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 224, 224, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 112, 112, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 112, 112, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 56, 56, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 56, 56, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 28, 28, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 50176)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │      25,690,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_7 (Activation)            │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,257,930 (100.17 MB)
#  Trainable params: 26,255,050 (100.16 MB)
#  Non-trainable params: 2,880 (11.25 KB)
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.0409 - loss: 2.9957
# Epoch 1: val_accuracy improved from -inf to 0.16667, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 47s 14s/step - accuracy: 0.0418 - loss: 2.9934 - val_accuracy: 0.1667 - val_loss: 2.3186
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.1449 - loss: 2.8654
# Epoch 2: val_accuracy did not improve from 0.16667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 9s/step - accuracy: 0.1392 - loss: 2.8922 - val_accuracy: 0.1333 - val_loss: 2.2924
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.1999 - loss: 2.5807
# Epoch 3: val_accuracy improved from 0.16667 to 0.26667, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 10s/step - accuracy: 0.1944 - loss: 2.5942 - val_accuracy: 0.2667 - val_loss: 2.2818
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.1612 - loss: 2.5103
# Epoch 4: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 39s 9s/step - accuracy: 0.1598 - loss: 2.5245 - val_accuracy: 0.2333 - val_loss: 2.2630
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.1226 - loss: 2.4864
# Epoch 5: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 40s 8s/step - accuracy: 0.1253 - loss: 2.4947 - val_accuracy: 0.2000 - val_loss: 2.2274
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.1671 - loss: 2.5155
# Epoch 6: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 9s/step - accuracy: 0.1726 - loss: 2.5160 - val_accuracy: 0.1667 - val_loss: 2.2190
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.1686 - loss: 2.3298
# Epoch 7: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 50s 14s/step - accuracy: 0.1709 - loss: 2.3274 - val_accuracy: 0.1667 - val_loss: 2.2132
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.1174 - loss: 2.5490
# Epoch 8: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 27s 9s/step - accuracy: 0.1214 - loss: 2.5432 - val_accuracy: 0.1667 - val_loss: 2.2140
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.1791 - loss: 2.2679
# Epoch 9: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 40s 9s/step - accuracy: 0.1787 - loss: 2.2651 - val_accuracy: 0.1667 - val_loss: 2.2201
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.2542 - loss: 2.0791
# Epoch 10: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 40s 9s/step - accuracy: 0.2406 - loss: 2.0937 - val_accuracy: 0.1667 - val_loss: 2.2127
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.1738 - loss: 2.2014
# Epoch 11: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 9s/step - accuracy: 0.1748 - loss: 2.1992 - val_accuracy: 0.1667 - val_loss: 2.1976
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.2147 - loss: 2.1993
# Epoch 12: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 40s 9s/step - accuracy: 0.2166 - loss: 2.1894 - val_accuracy: 0.1667 - val_loss: 2.1749
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.2429 - loss: 2.0279
# Epoch 13: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 9s/step - accuracy: 0.2433 - loss: 2.0303 - val_accuracy: 0.1667 - val_loss: 2.1594
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.3016 - loss: 2.0703
# Epoch 14: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 40s 8s/step - accuracy: 0.3040 - loss: 2.0661 - val_accuracy: 0.1667 - val_loss: 2.1576
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.2727 - loss: 2.1315
# Epoch 15: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 9s/step - accuracy: 0.2684 - loss: 2.1301 - val_accuracy: 0.1667 - val_loss: 2.1607
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.2593 - loss: 2.0570
# Epoch 16: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 9s/step - accuracy: 0.2639 - loss: 2.0558 - val_accuracy: 0.1667 - val_loss: 2.1668
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.2875 - loss: 1.9555
# Epoch 17: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 9s/step - accuracy: 0.2906 - loss: 1.9518 - val_accuracy: 0.1667 - val_loss: 2.1709
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.2808 - loss: 1.9092
# Epoch 18: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 9s/step - accuracy: 0.2884 - loss: 1.8870 - val_accuracy: 0.1667 - val_loss: 2.1766
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.2972 - loss: 1.7993
# Epoch 19: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 9s/step - accuracy: 0.2896 - loss: 1.8215 - val_accuracy: 0.1667 - val_loss: 2.1814
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.2615 - loss: 1.9705
# Epoch 20: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 25s 8s/step - accuracy: 0.2711 - loss: 1.9514 - val_accuracy: 0.1667 - val_loss: 2.1913
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.4183 - loss: 1.7211
# Epoch 21: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 42s 9s/step - accuracy: 0.4165 - loss: 1.7226 - val_accuracy: 0.1667 - val_loss: 2.2044
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.3953 - loss: 1.7581
# Epoch 22: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 9s/step - accuracy: 0.3937 - loss: 1.7624 - val_accuracy: 0.0667 - val_loss: 2.1956
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.3440 - loss: 1.6080
# Epoch 23: val_accuracy did not improve from 0.26667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 43s 9s/step - accuracy: 0.3441 - loss: 1.6242 - val_accuracy: 0.1667 - val_loss: 2.1693
# Epoch 23: early stopping

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np

# Load VGG16 base model (without top, pretrained on ImageNet)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze all convolutional layers

# Add custom head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(10, activation='softmax')(x)

# Create model (this was the part that broke)
model = Model(inputs=base_model.input, outputs=predictions)

# NOW we compile it (without any misplaced arguments)
model.compile(
    optimizer=Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
checkpoint = ModelCheckpoint(
    'vgg16_best_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    mode='max',
    verbose=1
)

# Train
history = model.fit(
    train_dataset,
    epochs=20,
    validation_data=test_dataset,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.1523 - loss: 13.6089
# Epoch 1: val_accuracy improved from -inf to 0.23333, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 81s 29s/step - accuracy: 0.1503 - loss: 13.6556 - val_accuracy: 0.2333 - val_loss: 3.3239
# Epoch 2/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.1775 - loss: 11.0585
# Epoch 2: val_accuracy improved from 0.23333 to 0.40000, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 80s 29s/step - accuracy: 0.1804 - loss: 10.7523 - val_accuracy: 0.4000 - val_loss: 2.4286
# Epoch 3/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19s/step - accuracy: 0.1656 - loss: 7.8847
# Epoch 3: val_accuracy improved from 0.40000 to 0.43333, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 84s 29s/step - accuracy: 0.1742 - loss: 7.8160 - val_accuracy: 0.4333 - val_loss: 1.8067
# Epoch 4/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.4413 - loss: 4.0877
# Epoch 4: val_accuracy improved from 0.43333 to 0.60000, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 79s 28s/step - accuracy: 0.4393 - loss: 4.0594 - val_accuracy: 0.6000 - val_loss: 1.3103
# Epoch 5/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.4235 - loss: 3.3085
# Epoch 5: val_accuracy did not improve from 0.60000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 79s 28s/step - accuracy: 0.4204 - loss: 3.4027 - val_accuracy: 0.5667 - val_loss: 1.1651
# Epoch 6/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19s/step - accuracy: 0.3662 - loss: 4.3144
# Epoch 6: val_accuracy improved from 0.60000 to 0.70000, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 84s 29s/step - accuracy: 0.3774 - loss: 4.3086 - val_accuracy: 0.7000 - val_loss: 1.0126
# Epoch 7/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.4301 - loss: 3.3644
# Epoch 7: val_accuracy improved from 0.70000 to 0.73333, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 99s 39s/step - accuracy: 0.4420 - loss: 3.3148 - val_accuracy: 0.7333 - val_loss: 0.9336
# Epoch 8/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.5810 - loss: 2.5255
# Epoch 8: val_accuracy improved from 0.73333 to 0.80000, saving model to vgg16_best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 122s 29s/step - accuracy: 0.5747 - loss: 2.4991 - val_accuracy: 0.8000 - val_loss: 0.9057
# Epoch 9/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.6069 - loss: 1.5532
# Epoch 9: val_accuracy did not improve from 0.80000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 79s 28s/step - accuracy: 0.6135 - loss: 1.5770 - val_accuracy: 0.7333 - val_loss: 0.9423
# Epoch 10/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19s/step - accuracy: 0.6122 - loss: 1.5103
# Epoch 10: val_accuracy did not improve from 0.80000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 82s 28s/step - accuracy: 0.6174 - loss: 1.4844 - val_accuracy: 0.7333 - val_loss: 0.9908
# Epoch 11/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.6649 - loss: 1.2855
# Epoch 11: val_accuracy did not improve from 0.80000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 84s 28s/step - accuracy: 0.6654 - loss: 1.2763 - val_accuracy: 0.7000 - val_loss: 0.9981
# Epoch 12/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19s/step - accuracy: 0.6895 - loss: 1.1281
# Epoch 12: val_accuracy did not improve from 0.80000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 82s 29s/step - accuracy: 0.6865 - loss: 1.1435 - val_accuracy: 0.7000 - val_loss: 0.9735
# Epoch 13/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.6634 - loss: 1.3386
# Epoch 13: val_accuracy did not improve from 0.80000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 82s 28s/step - accuracy: 0.6670 - loss: 1.3259 - val_accuracy: 0.7000 - val_loss: 0.9372
# Epoch 14/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.7645 - loss: 0.8460
# Epoch 14: val_accuracy did not improve from 0.80000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 80s 28s/step - accuracy: 0.7678 - loss: 0.8503 - val_accuracy: 0.7667 - val_loss: 0.8856
# Epoch 15/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.6902 - loss: 0.9887
# Epoch 15: val_accuracy did not improve from 0.80000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 96s 38s/step - accuracy: 0.6954 - loss: 0.9945 - val_accuracy: 0.7667 - val_loss: 0.8891
# Epoch 16/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19s/step - accuracy: 0.7675 - loss: 0.6921
# Epoch 16: val_accuracy did not improve from 0.80000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 123s 29s/step - accuracy: 0.7645 - loss: 0.6886 - val_accuracy: 0.7667 - val_loss: 0.8857
# Epoch 17/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.7125 - loss: 1.0068
# Epoch 17: val_accuracy did not improve from 0.80000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 82s 28s/step - accuracy: 0.7094 - loss: 0.9965 - val_accuracy: 0.7667 - val_loss: 0.8647
# Epoch 18/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.7712 - loss: 0.7783
# Epoch 18: val_accuracy did not improve from 0.80000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 79s 28s/step - accuracy: 0.7701 - loss: 0.7732 - val_accuracy: 0.7667 - val_loss: 0.8544
# Epoch 18: early stopping

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report
import numpy as np

# Get predictions
y_true = np.concatenate([y for _, y in test_dataset], axis=0)
y_pred_probs = model.predict(test_dataset)
y_pred = np.argmax(y_pred_probs, axis=1)

# Report
print(classification_report(y_true, y_pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 19s 19s/step
#               precision    recall  f1-score   support
#
#            0       0.50      0.80      0.62         5
#            1       1.00      0.80      0.89         5
#            2       0.83      1.00      0.91         5
#            3       1.00      0.80      0.89         5
#            4       0.80      0.80      0.80         5
#            5       0.67      0.40      0.50         5
#
#     accuracy                           0.77        30
#    macro avg       0.80      0.77      0.77        30
# weighted avg       0.80      0.77      0.77        30
