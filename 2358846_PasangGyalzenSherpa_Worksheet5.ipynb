# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the train directory path
train_dir = '/content/drive/MyDrive/FruitinAmazon/train'

# Get the list of class directories
class_dirs = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]
class_dirs.sort()  # Sort for consistent order
print(f"Found {len(class_dirs)} classes: {class_dirs}")

# Select one random image from each class
images = []
class_names = []
for class_dir in class_dirs:
    class_path = os.path.join(train_dir, class_dir)
    image_files = [f for f in os.listdir(class_path) if f.endswith(('.jpg', '.jpeg', '.png'))]
    if image_files:  # Ensure there’s at least one image
        random_image = random.choice(image_files)
        image_path = os.path.join(class_path, random_image)
        images.append(image_path)
        class_names.append(class_dir)

# Check if we have images to display
if not images:
    raise ValueError("No images found in the dataset!")

# Display images in a 2-row grid
rows = 2
cols = (len(images) + 1) // 2  # Ceiling division to fit all classes
fig, axes = plt.subplots(rows, cols, figsize=(15, 10))  # Adjust figure size as needed
fig.suptitle("Random Images from Each Class", fontsize=16)

# Flatten axes array for easier indexing
axes = axes.flatten()

# Plot each image
for i, (image_path, class_name) in enumerate(zip(images, class_names)):
    img = mpimg.imread(image_path)
    axes[i].imshow(img)
    axes[i].set_title(class_name)
    axes[i].axis('off')  # Hide axes

# Hide any unused subplots (if odd number of classes)
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Found 6 classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np

# Define dataset paths
train_dir = '/content/drive/MyDrive/FruitinAmazon/train'
test_dir = '/content/drive/MyDrive/FruitinAmazon/test'

# Load datasets
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(128, 128),
    batch_size=16,
    label_mode='categorical',
    shuffle=True
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(128, 128),
    batch_size=16,
    label_mode='categorical',
    shuffle=False
)

# Store the number of classes before mapping
num_classes = len(train_dataset.class_names)

# Normalize images
def normalize_img(image, label):
    return tf.cast(image, tf.float32) / 255.0, label

train_dataset = train_dataset.map(normalize_img)
test_dataset = test_dataset.map(normalize_img)

# Define CNN model
model = keras.Sequential([
    keras.Input(shape=(128, 128, 3)),
    layers.Conv2D(32, (3, 3), padding='same', strides=1, activation="relu"),  # Conv1
    layers.MaxPooling2D((2, 2), strides=2),                            # Pool1
    layers.Conv2D(32, (3, 3), padding='same', strides=1, activation="relu"),  # Conv2
    layers.MaxPooling2D((2, 2), strides=2),                            # Pool2
    layers.Flatten(),                                                  # Flatten
    layers.Dense(64, activation="relu"),                               # Hidden 1
    layers.Dense(128, activation="relu"),                              # Hidden 2
    layers.Dense(num_classes, activation="softmax")                    # Output (6)
])

model.summary()

# Compile model
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

checkpoint = ModelCheckpoint(
    'best_model.keras',  # Save best model
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=20,  # Stop after 20 epochs with no improvement
    mode='max',
    verbose=1
)

# Train model
histroy = model.fit(
    train_dataset,
    epochs=250,
    validation_data=test_dataset,
    callbacks=[checkpoint, early_stopping]
)

# Evaluate model
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.4f}")

# Make predictions on one batch
for images, labels in test_dataset.take(1):
    predictions = model.predict(images)
    predicted_labels = np.argmax(predictions, axis=1)
    actual_labels = np.argmax(labels, axis=1)
    print("Predicted labels:", predicted_labels[:5])
    print("Actual labels: ", actual_labels[:5])
    break
# Out:
# Found 90 files belonging to 6 classes.
# Found 30 files belonging to 6 classes.
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 64, 64, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 64)                  │       2,097,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 6)                   │             774 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,116,454 (8.07 MB)
#  Trainable params: 2,116,454 (8.07 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.0877 - loss: 2.1365
# Epoch 1: val_accuracy improved from -inf to 0.16667, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 461ms/step - accuracy: 0.0990 - loss: 2.1397 - val_accuracy: 0.1667 - val_loss: 1.8557
# Epoch 2/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.1743 - loss: 1.7837
# Epoch 2: val_accuracy improved from 0.16667 to 0.23333, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 399ms/step - accuracy: 0.1780 - loss: 1.7856 - val_accuracy: 0.2333 - val_loss: 1.6950
# Epoch 3/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.3604 - loss: 1.6594
# Epoch 3: val_accuracy improved from 0.23333 to 0.50000, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 515ms/step - accuracy: 0.3661 - loss: 1.6546 - val_accuracy: 0.5000 - val_loss: 1.5266
# Epoch 4/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.6160 - loss: 1.4149
# Epoch 4: val_accuracy did not improve from 0.50000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 602ms/step - accuracy: 0.6089 - loss: 1.4158 - val_accuracy: 0.3333 - val_loss: 1.3432
# Epoch 5/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.5541 - loss: 1.1934
# Epoch 5: val_accuracy did not improve from 0.50000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 352ms/step - accuracy: 0.5527 - loss: 1.1951 - val_accuracy: 0.5000 - val_loss: 1.2114
# Epoch 6/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.7309 - loss: 0.9705
# Epoch 6: val_accuracy improved from 0.50000 to 0.66667, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - accuracy: 0.7312 - loss: 0.9639 - val_accuracy: 0.6667 - val_loss: 1.0074
# Epoch 7/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9181 - loss: 0.5844
# Epoch 7: val_accuracy improved from 0.66667 to 0.73333, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 543ms/step - accuracy: 0.9139 - loss: 0.5823 - val_accuracy: 0.7333 - val_loss: 0.9739
# Epoch 8/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.9177 - loss: 0.3554
# Epoch 8: val_accuracy did not improve from 0.73333
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 490ms/step - accuracy: 0.9167 - loss: 0.3536 - val_accuracy: 0.6667 - val_loss: 0.8988
# Epoch 9/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9395 - loss: 0.2023
# Epoch 9: val_accuracy did not improve from 0.73333
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 348ms/step - accuracy: 0.9402 - loss: 0.1999 - val_accuracy: 0.7000 - val_loss: 1.0274
# Epoch 10/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9842 - loss: 0.1229
# Epoch 10: val_accuracy improved from 0.73333 to 0.76667, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 379ms/step - accuracy: 0.9817 - loss: 0.1222 - val_accuracy: 0.7667 - val_loss: 0.8891
# Epoch 11/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 1.0000 - loss: 0.0575
# Epoch 11: val_accuracy did not improve from 0.76667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 357ms/step - accuracy: 1.0000 - loss: 0.0573 - val_accuracy: 0.7333 - val_loss: 0.8798
# Epoch 12/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 1.0000 - loss: 0.0163
# Epoch 12: val_accuracy improved from 0.76667 to 0.80000, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 394ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 0.8000 - val_loss: 0.6750
# Epoch 13/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 13: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 627ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.7667 - val_loss: 0.9796
# Epoch 14/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 14: val_accuracy improved from 0.80000 to 0.86667, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 384ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.8667 - val_loss: 0.9157
# Epoch 15/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 15: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 360ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8333 - val_loss: 0.9372
# Epoch 16/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 1.0000 - loss: 9.1033e-04
# Epoch 16: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 350ms/step - accuracy: 1.0000 - loss: 9.1019e-04 - val_accuracy: 0.8000 - val_loss: 0.9768
# Epoch 17/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 1.0000 - loss: 6.8530e-04
# Epoch 17: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 1.0000 - loss: 6.9291e-04 - val_accuracy: 0.7667 - val_loss: 1.0020
# Epoch 18/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 642ms/step - accuracy: 1.0000 - loss: 5.7772e-04
# Epoch 18: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 749ms/step - accuracy: 1.0000 - loss: 5.8013e-04 - val_accuracy: 0.8000 - val_loss: 1.0105
# Epoch 19/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 1.0000 - loss: 4.4007e-04
# Epoch 19: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 350ms/step - accuracy: 1.0000 - loss: 4.4348e-04 - val_accuracy: 0.8333 - val_loss: 1.0358
# Epoch 20/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 1.0000 - loss: 3.7658e-04
# Epoch 20: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step - accuracy: 1.0000 - loss: 3.7728e-04 - val_accuracy: 0.8667 - val_loss: 1.0990
# Epoch 21/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 1.0000 - loss: 3.3050e-04
# Epoch 21: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 354ms/step - accuracy: 1.0000 - loss: 3.2941e-04 - val_accuracy: 0.8000 - val_loss: 1.1155
# Epoch 22/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 1.0000 - loss: 3.0316e-04
# Epoch 22: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 373ms/step - accuracy: 1.0000 - loss: 3.0143e-04 - val_accuracy: 0.8000 - val_loss: 1.0825
# Epoch 23/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 1.0000 - loss: 2.4286e-04
# Epoch 23: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 630ms/step - accuracy: 1.0000 - loss: 2.4536e-04 - val_accuracy: 0.8000 - val_loss: 1.0590
# Epoch 24/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 1.0000 - loss: 2.0616e-04
# Epoch 24: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 520ms/step - accuracy: 1.0000 - loss: 2.1065e-04 - val_accuracy: 0.8000 - val_loss: 1.0811
# Epoch 25/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 1.0000 - loss: 2.5094e-04
# Epoch 25: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 362ms/step - accuracy: 1.0000 - loss: 2.4635e-04 - val_accuracy: 0.8000 - val_loss: 1.0768
# Epoch 26/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 1.0000 - loss: 2.1260e-04
# Epoch 26: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 347ms/step - accuracy: 1.0000 - loss: 2.1129e-04 - val_accuracy: 0.8000 - val_loss: 1.0627
# Epoch 27/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 1.0000 - loss: 2.2924e-04
# Epoch 27: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 1.0000 - loss: 2.2304e-04 - val_accuracy: 0.8000 - val_loss: 1.0744
# Epoch 28/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 1.0000 - loss: 1.6164e-04
# Epoch 28: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 549ms/step - accuracy: 1.0000 - loss: 1.6328e-04 - val_accuracy: 0.8000 - val_loss: 1.0970
# Epoch 29/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 1.0000 - loss: 1.7242e-04
# Epoch 29: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 344ms/step - accuracy: 1.0000 - loss: 1.7089e-04 - val_accuracy: 0.8000 - val_loss: 1.0975
# Epoch 30/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 1.0000 - loss: 1.5128e-04
# Epoch 30: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 353ms/step - accuracy: 1.0000 - loss: 1.5110e-04 - val_accuracy: 0.8000 - val_loss: 1.0785
# Epoch 31/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 1.0000 - loss: 1.4409e-04
# Epoch 31: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 349ms/step - accuracy: 1.0000 - loss: 1.4377e-04 - val_accuracy: 0.8000 - val_loss: 1.1075
# Epoch 32/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 1.0000 - loss: 1.1179e-04
# Epoch 32: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 352ms/step - accuracy: 1.0000 - loss: 1.1459e-04 - val_accuracy: 0.8000 - val_loss: 1.0953
# Epoch 33/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 1.0000 - loss: 1.1614e-04
# Epoch 33: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 604ms/step - accuracy: 1.0000 - loss: 1.1734e-04 - val_accuracy: 0.8000 - val_loss: 1.0940
# Epoch 34/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 1.0000 - loss: 9.4370e-05
# Epoch 34: val_accuracy did not improve from 0.86667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 357ms/step - accuracy: 1.0000 - loss: 9.7481e-05 - val_accuracy: 0.8000 - val_loss: 1.0942
# Epoch 34: early stopping
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8458 - loss: 0.7843
# Test accuracy: 0.8000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# Predicted labels: [0 0 0 0 0]
# Actual labels:  [0 0 0 0 0]

# %%
history_dict = histroy.history
epochs = range(1, len(history_dict['loss']) + 1)
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

# Create subplots: 1 row, 2 columns
plt.figure(figsize=(12, 5))

# Plot 1: Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot 2: Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, 'b-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Adjust layout and display
plt.tight_layout()
plt.show()

# %%
model.save('fruitdetection.h5')
loaded_model = keras.models.load_model('fruitdetection.h5')

print('model saved to fruitdetection.h5')
print('model loaded from fruitdetection.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved to fruitdetection.h5
# model loaded from fruitdetection.h5

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from sklearn.metrics import classification_report
loaded_model = keras.models.load_model('fruitdetection.h5')
print("Model loaded for predictions")

# Collect all test images and labels
all_images = []
all_labels = []
for images, labels in test_dataset:
    all_images.append(images.numpy())
    all_labels.append(labels.numpy())
    # Load dataset
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/FruitinAmazon/test",
    image_size=(224, 224),
    batch_size=32
)

# Concatenate batches into single arrays
test_images = np.concatenate(all_images, axis=0)  # Shape: (30, 128, 128, 3)
test_labels_onehot = np.concatenate(all_labels, axis=0)  # Shape: (30, 6)

# Make predictions
predictions = loaded_model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)  # Convert probabilities to class indices
true_labels = np.argmax(test_labels_onehot, axis=1)  # Convert one-hot to class indices

# Get class names from the dataset
class_names = test_dataset.class_names
print(f"Class names: {class_names}")

# Generate classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)
print("Classification Report:\n", report)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded for predictions
# Found 30 files belonging to 6 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Class names: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']
# Classification Report:
#                precision    recall  f1-score   support
#
#         acai       0.62      1.00      0.77         5
#      cupuacu       0.80      0.80      0.80         5
#     graviola       1.00      1.00      1.00         5
#      guarana       0.80      0.80      0.80         5
#      pupunha       0.80      0.80      0.80         5
#       tucuma       1.00      0.40      0.57         5
#
#     accuracy                           0.80        30
#    macro avg       0.84      0.80      0.79        30
# weighted avg       0.84      0.80      0.79        30
